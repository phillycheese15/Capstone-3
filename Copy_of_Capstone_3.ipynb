# %% [markdown]
# <a href="https://colab.research.google.com/github/phillycheese15/Capstone-3-/blob/main/Copy_of_Capstone_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# THIS IS AN IMPORT I HAD WROTE THE CODE AND HAD TO GET IT MOUNTED THROUGH GOOGLE AND GOT IT AUTHROZIED AS WELL

# %% [markdown]
# This is my data set called NBA games stats 2014-2018 i chose this data set because i am a data analyts and I love basketball and its something i want to get into that feild
#
# I will be going into sports analytics feild to so this is good practice for me
#
#
# My source of getting this data is from kaggle https://www.kaggle.com/ionaskel/nba-games-stats-from-2014-to-2018
#
# My two hypothesis are i think the average for scoring is 120 points
#
# My second hypothesis is the away team scores 5 points more than the home team
#
# Here is the link to my CSV https://drive.google.com/file/d/1Az32JFotTEavECcu7_hWVigiFZc59KdQ/view?usp=sharing
#
# I have done over 10 plus different exploratory data visuals to look over and find out what works for me to present
#
# My visualzations can help coaches on all levels of baasketball and it will give them an edge over there opponenets
#
# Enjoy the data

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# I IMPORTED PANDAS TO MY DATA SET TO HELP SET IT UP SO I CAN SEE MY CONTENT OF MY DATA

# %%
import pandas as pd

df = pd.read_csv('/content/nba.games.stats (1).csv')
df.head()
# Out:
#    Unnamed: 0 Team  Game  ... Opp.Blocks Opp.Turnovers Opp.TotalFouls
# 0           1  ATL     1  ...          9             9             22
# 1           2  ATL     2  ...          5            18             26
# 2           3  ATL     3  ...          9            19             15
# 3           4  ATL     4  ...          7            19             30
# 4           5  ATL     5  ...          6            15             29
#
# [5 rows x 41 columns]

# %% [markdown]
# -- In this section importing seaborn on my data set so i can use it for my data
#
# -- Click the runtime button so the data can run

# %%
import pandas as pd
import seaborn as sns 
sns.set()

# %%
df['Team'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0       ATL
# 1       ATL
# 2       ATL
# 3       ATL
# 4       ATL
#        ...
# 9835    WAS
# 9836    WAS
# 9837    WAS
# 9838    WAS
# 9839    WAS
# Name: Team, Length: 9840, dtype: object>

# %%
df.info('team')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9840 entries, 0 to 9839
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                9840 non-null   int64
#  1   Team                      9840 non-null   object
#  2   Game                      9840 non-null   int64
#  3   Date                      9840 non-null   object
#  4   Home                      9840 non-null   object
#  5   Opponent                  9840 non-null   object
#  6   WINorLOSS                 9840 non-null   object
#  7   TeamPoints                9840 non-null   int64
#  8   OpponentPoints            9840 non-null   int64
#  9   FieldGoals                9840 non-null   int64
#  10  FieldGoalsAttempted       9840 non-null   int64
#  11  FieldGoals.               9840 non-null   float64
#  12  X3PointShots              9840 non-null   int64
#  13  X3PointShotsAttempted     9840 non-null   int64
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Team', 'Game', 'Date', 'Home', 'Opponent', 'WINorLOSS',
#        'TeamPoints', 'OpponentPoints', 'FieldGoals', 'FieldGoalsAttempted',
#        'FieldGoals.', 'X3PointShots', 'X3PointShotsAttempted', 'X3PointShots.',
#        'FreeThrows', 'FreeThrowsAttempted', 'FreeThrows.', 'OffRebounds',
#        'TotalRebounds', 'Assists', 'Steals', 'Blocks', 'Turnovers',
#        'TotalFouls', 'Opp.FieldGoals', 'Opp.FieldGoalsAttempted',
#        'Opp.FieldGoals.', 'Opp.3PointShots', 'Opp.3PointShotsAttempted',
#        'Opp.3PointShots.', 'Opp.FreeThrows', 'Opp.FreeThrowsAttempted',
#        'Opp.FreeThrows.', 'Opp.OffRebounds', 'Opp.TotalRebounds',
#        'Opp.Assists', 'Opp.Steals', 'Opp.Blocks', 'Opp.Turnovers',
#        'Opp.TotalFouls'],
#       dtype='object')

# %% [markdown]
# **Exploring different data visuals for 3POINT SHOTS and ATTEMPTS!!**
#
# --- # I am exploring Different visuals on how the 3 point shots and attempts have impacted the game and how important it is and how 3 is greater than 2

# %%
sns.scatterplot(x="X3PointShots", y="X3PointShotsAttempted", data= df)

# %%
sns.scatterplot(x="X3PointShots", y="X3PointShotsAttempted", hue="X3PointShots", data=df),df.loc[pd.DatetimeIndex(df['Date']).year==2014]
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fe885664f98>,
#        Unnamed: 0 Team  Game  ... Opp.Blocks Opp.Turnovers Opp.TotalFouls
#  0              1  ATL     1  ...          9             9             22
#  1              2  ATL     2  ...          5            18             26
#  2              3  ATL     3  ...          9            19             15
#  3              4  ATL     4  ...          7            19             30
#  4              5  ATL     5  ...          6            15             29
#  ...          ...  ...   ...  ...        ...           ...            ...
#  2404        2729  WAS    27  ...          7            10             14
#  2405        2829  WAS    28  ...          4             7             15
#  2406        2929  WAS    29  ...          2            18             15
#  2407        3029  WAS    30  ...          1            18             20
#  2408        3137  WAS    31  ...          5             7             22
#
# ...

# %%
ax = sns.distplot(df['X3PointShots'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
ax = sns.distplot(df['X3PointShotsAttempted'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
ax = sns.distplot(df['X3PointShotsAttempted'], bins=40)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
ax = sns.distplot(df['X3PointShots'], bins=40)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.scatterplot(x="X3PointShots", y="X3PointShotsAttempted", hue="Team", data=df)

# %%
sns.jointplot(x="X3PointShots", y="X3PointShotsAttempted", data=df)

# %% [markdown]
# **Exploratory data for Hypothese testing**
#
# --- I created a scatterplot on 3points shots with the team points and i was looking at to see does the basketball teams being at home do they shoot more 3's at home or away.

# %%
sns.scatterplot(x="X3PointShots", y="TeamPoints", hue="Home", data=df)

# %% [markdown]
# **EXploratory Data**

# %%
sns.scatterplot(x="FreeThrows", y="TeamPoints", hue="Home", data=df)

# %% [markdown]
# **Exploratory Data**

# %%
ax = sns.distplot(df['TeamPoints'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **Exploratory Data**

# %%
sns.scatterplot(x="FieldGoals", y="FieldGoalsAttempted", data=df)

# %% [markdown]
# **EXPLORATORY Data**

# %%
sns.scatterplot(x="FreeThrows.", y="FreeThrowsAttempted", data=df)

# %% [markdown]
# **Exploratory Data**

# %%
sns.scatterplot(x="Team", y="TeamPoints", hue="Home", data=df)

# %% [markdown]
# **Exploratory Data**

# %%
sns.scatterplot(x="Date", y="TeamPoints", hue="WINorLOSS", data=df)

# %% [markdown]
# **Exploartory Data**

# %%
ax = sns.distplot(df['TeamPoints'], bins=110)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **Finished Data**

# %%
ax = sns.distplot(df['X3PointShots'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **Finished Data**
#
# i used Box plot to find the average for every team points and as it looks like about 110-115 points a game

# %%
sns.boxplot(y="TeamPoints", data=df)

# %% [markdown]
# **Finished** Data
#
# I used Box Plot to find the average for team points

# %%
sns.boxplot(y="TeamPoints", x="Home", data=df)

# %% [markdown]
# **Descritives Stats Home/ Away Team Points**

# %%
homedf=df[df['Home']=='Home']['TeamPoints']

# %%
homedf.head()
# Out:
# 1    102
# 4    103
# 6    100
# 7    114
# 9    109
# Name: TeamPoints, dtype: int64

# %%
df[df['Home']=='Away']['TeamPoints']
# Out:
# 0       102
# 2        92
# 3       119
# 5        91
# 8        94
#        ...
# 9832     92
# 9834     94
# 9835    104
# 9836    115
# 9839     92
# Name: TeamPoints, Length: 4920, dtype: int64

# %%
Awaydf=df[df['Home']=='Away']['TeamPoints']

# %% [markdown]
# **I Imported Scipy here for my Test for my second hypothesis**

# %%
import scipy
scipy.stats.ttest_ind(homedf,Awaydf)
# Out:
# Ttest_indResult(statistic=10.575906861044029, pvalue=5.313973148706086e-26)

# %%
Awaydf.head()
# Out:
# 0    102
# 2     92
# 3    119
# 5     91
# 8     94
# Name: TeamPoints, dtype: int64

# %% [markdown]
# **I imported numpy and Datemtime to help with my Data set**

# %%
import numpy as np
import datetime

# %% [markdown]
# **This is my data for my first hypothesis Null hyptothesis There is no difference in scoring in 2014 vs 2018**

# %%
df2014 = df.loc[pd.DatetimeIndex(df['Date']).year==2014]
df2014.head()
# Out:
#    Unnamed: 0 Team  Game  ... Opp.Blocks Opp.Turnovers Opp.TotalFouls
# 0           1  ATL     1  ...          9             9             22
# 1           2  ATL     2  ...          5            18             26
# 2           3  ATL     3  ...          9            19             15
# 3           4  ATL     4  ...          7            19             30
# 4           5  ATL     5  ...          6            15             29
#
# [5 rows x 41 columns]

# %%
teampoints2014 = df2014['TeamPoints']
teampoints2014
# Out:
# 0       102
# 1       102
# 2        92
# 3       119
# 4       103
#        ...
# 2404     91
# 2405    102
# 2406    101
# 2407    104
# 2408     87
# Name: TeamPoints, Length: 962, dtype: int64

# %%
df2018 = df.loc[pd.DatetimeIndex(df['Date']).year==2018]
df2018.head()
# Out:
#       Unnamed: 0 Team  Game  ... Opp.Blocks Opp.Turnovers Opp.TotalFouls
# 7416        3790  ATL    37  ...          4            21             22
# 7417        3890  ATL    38  ...          5            15             20
# 7418        3990  ATL    39  ...          6            18             25
# 7419        4090  ATL    40  ...          9            16             25
# 7420       41129  ATL    41  ...          6            12             18
#
# [5 rows x 41 columns]

# %%
teampoints2018 = df2018['TeamPoints']
teampoints2018
# Out:
# 7416    103
# 7417     89
# 7418    113
# 7419    107
# 7420    110
#        ...
# 9835    104
# 9836    115
# 9837     97
# 9838    113
# 9839     92
# Name: TeamPoints, Length: 1372, dtype: int64

# %% [markdown]
# Here are my visuals for my first hypothesis and some of them are just exploratoty visuals not all were used in the presentation. I wanted to leeave them up to show the different typesin data

# %%
sns.boxplot(y="TeamPoints", data=df2014)

# %%
sns.boxplot(y="TeamPoints", data=df2018)

# %%
ax = sns.distplot(df2014['TeamPoints'], bins=30)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df2014=df[df['TeamPoints']=='TeamPoints']

# %%
df2018=df[df['TeamPoints']=='TeamPoints']

# %%
## This is my T-Test for my First Hypotheisis

# %%
import scipy
scipy.stats.ttest_ind(df2014,df2018)
# Out:
# Ttest_indResult(statistic=nan, pvalue=nan)

# %% [markdown]
# **Combining data**
#
# --- # combine the date witht the year 2014-2018

# %%
df.loc[pd.DatetimeIndex(df['Date']).year==2014],df.loc[pd.DatetimeIndex(df['Date']).year==2018]
# Out:
# (      Unnamed: 0 Team  Game  ... Opp.Blocks Opp.Turnovers Opp.TotalFouls
#  0              1  ATL     1  ...          9             9             22
#  1              2  ATL     2  ...          5            18             26
#  2              3  ATL     3  ...          9            19             15
#  3              4  ATL     4  ...          7            19             30
#  4              5  ATL     5  ...          6            15             29
#  ...          ...  ...   ...  ...        ...           ...            ...
#  2404        2729  WAS    27  ...          7            10             14
#  2405        2829  WAS    28  ...          4             7             15
#  2406        2929  WAS    29  ...          2            18             15
#  2407        3029  WAS    30  ...          1            18             20
#  2408        3137  WAS    31  ...          5             7             22
#
#  [962 rows x 41 columns],
# ...

# %% [markdown]
# With the data you saw above and the visuals you saw this would gives coaches any defensive coordinator a cutting egde of how to defened better and you can stragize with some different ways to defend players who wants to shoot the three  Here are a few ideas on how to
#
# 1. zone defenses
# 2. close out efforts, high hands
# 3. Box and One
